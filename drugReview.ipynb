# %%
import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt  
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn import metrics
import numpy
import pandas as pd
from urllib.request import urlopen
import scipy.optimize
import random
from collections import defaultdict
import nltk
import string
from nltk.stem.porter import *
from nltk import word_tokenize 
from nltk.util import ngrams
from collections import Counter

# %matplotlib inline
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/irenemao/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df = pd.read_csv("drugsComTrain_raw.tsv",delimiter='\t')

# %%
df.head()
# Out:
#    Unnamed: 0                  drugName                     condition  \
# 0      206461                 Valsartan  Left Ventricular Dysfunction
# 1       95260                Guanfacine                          ADHD
# 2       92703                    Lybrel                 Birth Control
# 3      138000                Ortho Evra                 Birth Control
# 4       35696  Buprenorphine / naloxone             Opiate Dependence
#
#                                               review  rating  \
# 0  "It has no side effect, I take it in combinati...     9.0
# 1  "My son is halfway through his fourth week of ...     8.0
# 2  "I used to take another oral contraceptive, wh...     5.0
# 3  "This is my first time using any form of birth...     8.0
# 4  "Suboxone has completely turned my life around...     9.0
#
#                 date  usefulCount
# 0       May 20, 2012           27
# 1     April 27, 2010          192
# 2  December 14, 2009           17
# 3   November 3, 2015           10
# ...

# %%
condition = df['condition'].to_list()
len(set(condition))
# Out:
# 1

# %%
name = df['drugName'].to_list()
len(set(name))
# Out:
# 3436

# %%
len(df)
# Out:
# 161297

# %% [markdown]
# #### 1. Identify effectiveness and type of side effect of a drug based on reviews
# #### 2. Cross-domain

# %%
wordCount = defaultdict(int)

for review in df['review']:
    review = review.translate(str.maketrans('', '', string.punctuation)).lower()
    token = nltk.word_tokenize(review)
    bigram = list(ngrams(token, 2)) 
    for i in bigram:
        words = i[0]+' '+i[1]
        wordCount[words] += 1

# %%
wordCount
# Out:
# defaultdict(int,
#             {'it has': 12444,
#              'has no': 268,
#              'no side': 7441,
#              'side effect': 7117,
#              'effect i': 1701,
#              'i take': 10659,
#              'take it': 9957,
#              'it in': 3339,
#              'in combination': 358,
#              'combination of': 504,
#              'of bystolic': 19,
#              'bystolic 5': 9,
#              '5 mg': 856,
#              'mg and': 1131,
#              'and fish': 14,
#              'fish oil': 55,
#              'my son': 1593,
#              'son is': 208,
#              'is halfway': 2,
#              'halfway through': 152,
#              'through his': 11,
#              'his fourth': 4,
#              'fourth week': 97,
#              'week of': 1703,
#              'of intuniv': 12,
#              'intuniv we': 8,
#              'we became': 4,
#              'became concerned': 11,
#              'concerned when': 12,
# ...
